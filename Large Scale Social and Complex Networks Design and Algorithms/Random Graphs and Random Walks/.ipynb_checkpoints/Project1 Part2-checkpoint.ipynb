# %%
library('igraph')
library('Matrix')
library('pracma')
# Out:
# Attaching package: ‘igraph’
#
# The following objects are masked from ‘package:stats’:
#
#     decompose, spectrum
#
# The following object is masked from ‘package:base’:
#
#     union
#
#
# Attaching package: ‘pracma’
#
# The following objects are masked from ‘package:Matrix’:
#
#     expm, lu, tril, triu

# %% [markdown]
# # 1. Random walk on Erdös-Rényi networks

# %%
# creat 1000 nodes with p = 0.01

set.seed(0)
g1 <- random.graph.game(1000, p = 0.01, directed = F)
plot(g1,vertex.size=4, vertex.label.cex=0.7)
# Out:
# Plot with title “”

# %%
create_transition_matrix = function (g){
    
    # WARNING: make sure your graph is connected (you might input GCC of your graph)
    
    vs = V(g)
    n = vcount(g)
    adj = as_adjacency_matrix(g)
    adj[diag(rowSums(adj) == 0)] = 1  # handle if the user is using the function for networks with isolated nodes by creating self-edges
    z = matrix(rowSums(adj, , 1))
    
    transition_matrix = adj / repmat(z, 1, n)  # normalize to get probabilities
    
    return(transition_matrix)
}

# %%
random_walk = function (g, num_steps, start_node, transition_matrix = NULL){
    if(is.null(transition_matrix))
        transition_matrix = create_transition_matrix(g)
        
    v = start_node
    for(i in 1:num_steps){
        PMF = transition_matrix[v, ]
        v = sample(1:vcount(g), 1, prob = PMF)        
    }
    
    return(v)
}

# %%
start_node = 10
l = c()
s_t.mean = c()
s_t.sd = c()
node_degree = c()

for (steps in 1:100) {
    v_last = random_walk(g1, steps, start_node)
    shortpath = shortest.paths(g1, start_node, v_last)
    l <- c(l, shortpath)
    s_t.mean <- c(s_t.mean, mean(l))
    s_t.sd <- c(s_t.sd, sd(l))
    node_degree <- c(node_degree, degree(g1, v_last))
}
print(mean(s_t.mean))
print(mean(s_t.std))

# %%
layout(matrix(c(1,2,3,4), 2, 2, byrow = TRUE))
plot(s_t.mean, main="the avg distance vs step",xlab="step",ylab="avg distance")
plot(s_t.sd, main="the std of the distance vs step",xlab="step",ylab="std")
plot(node_degree, main="node degree vs graph degree",xlab="step",ylab="degree")
par(degree.distribution(g1)[1:100], new=TRUE)
# Out:
# Plot with title “node degree vs graph degree”

# %%
# creat 100 nodes with p = 0.01

set.seed(0)
g2 <- random.graph.game(100, p = 0.01, directed = F)
plot(g2,vertex.size=4, vertex.label.cex=0.7)
# Out:
# Plot with title “”

# %%
start_node = 75
l = c()
s_t.mean = c()
s_t.sd = c()
node_degree = c()

for (steps in 1:100) {
    v_last = random_walk(g2, steps, start_node)
    shortpath = shortest.paths(g2, start_node, v_last)
    l <- c(l, shortpath)
    s_t.mean <- c(s_t.mean, mean(l))
    s_t.sd <- c(s_t.sd, sd(l))
    node_degree <- c(node_degree, degree(g1, g = v_last))
}
# Out:
# Error in degree(g1, g = v_last): Not a graph object
# Traceback:
#
# 1. degree(g1, g = v_last)
# 2. stop("Not a graph object")

# %%
layout(matrix(c(1,2,3,4), 2, 2, byrow = TRUE))
plot(s_t.mean, main="the avg distance vs step",xlab="step",ylab="avg distance")
plot(s_t.sd, main="the std of the distance vs step",xlab="step",ylab="std")
plot(node_degree, main="node degree vs graph degree",xlab="step",ylab="degree")
#par(degree.distribution(g1)[1:100], new=TRUE)
# Out:
# Plot with title “node degree vs graph degree”
