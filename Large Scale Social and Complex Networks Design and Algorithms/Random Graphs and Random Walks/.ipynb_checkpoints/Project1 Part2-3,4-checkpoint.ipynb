# %% [markdown]
# # Part 2-3 PageRank

# %%
library('igraph')
library('Matrix')
library('pracma')
# Out:
# Attaching package: ‘igraph’
#
# The following objects are masked from ‘package:stats’:
#
#     decompose, spectrum
#
# The following object is masked from ‘package:base’:
#
#     union
#
#
# Attaching package: ‘pracma’
#
# The following objects are masked from ‘package:Matrix’:
#
#     expm, lu, tril, triu

# %%
set.seed(0)
g1 = sample_pa(1000, m = 4, directed = T)

# %%
create_transition_matrix = function (g){
    
    # WARNING: make sure your graph is connected (you might input GCC of your graph)
    
    vs = V(g)
    n = vcount(g)
    adj = as_adjacency_matrix(g)
    adj[diag(rowSums(adj) == 0)] = 1  
    z = matrix(rowSums(adj, , 1))
    
    transition_matrix = adj / repmat(z, 1, n)  # normalize to get probabilities
    
    return(transition_matrix)
}

# %%
random_walk_tele = function (g, num_steps, start_node, transition_matrix = NULL, tele, probvec){
    if(is.null(transition_matrix))
        transition_matrix = create_transition_matrix(g)
        
    v = start_node
    for(i in 1:num_steps){
        #fprintf('Step %d: %d\n', i, v)  
        PMF = transition_matrix[v, ]
        v = sample(1:vcount(g), 1, prob = PMF)
        # teleportation
        if (runif(1, 0, 1) < tele)
            v = sample(1:vcount(g), 1)
        probvec[v] = probvec[v] + 1
    }
    
    return(probvec)
}

# %%
graph = g1
transition_matrix = create_transition_matrix(graph)
probvec = integer(vcount(graph))
steps = 100
for (start_node in 1:vcount(graph)) {
    probvec = random_walk_tele(graph, steps, start_node, transition_matrix, tele = 0, probvec)
}

# %%
prob = probvec / 100000
node_degree = degree(g1, mode = 'in')
plot(node_degree, prob, main = 'Degree of this node vs prob', xlab = 'degree', ylab = 'prob')
#hist(node_degree, probability = T)
# Out:
# Plot with title “Degree of this node vs prob”

# %% [markdown]
# ## (b)

# %%
graph = g1
transition_matrix = create_transition_matrix(graph)
probvec = integer(vcount(graph))
steps = 100
for (start_node in 1:vcount(graph)) {
    probvec = random_walk_tele(graph, steps, start_node, transition_matrix, tele = 0.15, probvec)
}

# %%
prob2 = probvec / 100000
node_degree = degree(g1, mode = 'in')
plot(node_degree, prob2, main = 'Degree of this node vs prob', xlab = 'degree', ylab = 'prob')
# Out:
# Plot with title “Degree of this node vs prob”

# %%
#plot(density(prob2))

# %% [markdown]
# # Part 2-4 Personalized PageRank

# %%
prob3 = page_rank(g1, directed = TRUE, damping = 0.85, personalized = prob2)$vector

# %%
plot(node_degree, prob3, main = 'Degree of this node vs prob', xlab = 'degree', ylab = 'prob')
# Out:
# Plot with title “Degree of this node vs prob”

# %% [markdown]
# ### b

# %%
# get two median index
order(prob3)[500]
order(prob3)[501]
# Out:
# [1] 867
# [1] 878

# %%
random_walk_telemedian = function (g, num_steps, start_node, transition_matrix = NULL, tele, probvec){
    if(is.null(transition_matrix))
        transition_matrix = create_transition_matrix(g)
        
    v = start_node
    for(i in 1:num_steps){
        #fprintf('Step %d: %d\n', i, v)  
        PMF = transition_matrix[v, ]
        v = sample(1:vcount(g), 1, prob = PMF)
        # teleportation
        if (runif(1, 0, 1) < tele)
            if (runif(1, 0, 1) <= 0.5)
                v = 867
            if (runif(1, 0, 1) > 0.5)
                v = 878
        probvec[v] = probvec[v] + 1
    }
    
    return(probvec)
}

# %%
graph = g1
transition_matrix = create_transition_matrix(graph)
probvec = integer(vcount(graph))
steps = 100
for (start_node in 1:vcount(graph)) {
    probvec = random_walk_telemedian(graph, steps, start_node, transition_matrix, tele = 0.15, probvec)
}

# %%
prob4 = probvec / 100000
node_degree = degree(g1, mode = 'in')
plot(node_degree, prob4, main = 'Degree of this node vs prob', xlab = 'degree', ylab = 'prob')
# Out:
# Plot with title “Degree of this node vs prob”
