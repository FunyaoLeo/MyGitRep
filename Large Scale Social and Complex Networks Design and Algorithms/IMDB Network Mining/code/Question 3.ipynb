# %%
library('igraph')
library('Matrix')

# %% [markdown]
# ## Question 3: Pairing

# %%
path <- "C:/Users/Scott/GOOGLE/EE232/P4/actor_actress_weighted_double.csv"
el <- read.csv(path)
num_el <- as.matrix(el)
#el[,1] <- as.character(el[,1])
#el[,2] <- as.character(el[,2])
#el <- as.matrix(el)
#g <- graph.edgelist(el[,1:2])
#E(g)$weight <- as.numeric(el[,3])
# Out:
# Error: cannot allocate vector of size 541.3 Mb
# Traceback:
#
# 1. graph.edgelist(el[, 1:2])
# 2. graph(unname(ids[t(el)]), directed = directed)
# 3. unname(ids[t(el)])

# %%
name_id <- read.csv("C:/Users/Scott/GOOGLE/EE232/P4/name_id_list.csv")

getID <- function(name_id,name){
    actorNode <- which(name_id == name)-1
    return(actorNode)
}

getName <- function(name_id,ID){
    actorName <- name_id[ID+1,1]
    return(actorName)
}

# %%
getParing <- function(inputName){
    actorInput <- getID(name_id,inputName)
    Prob <- numeric()
    line <- which(num_el[,1] == actorInput)
    for(i in 1:length(line)){
        Prob[i] <- num_el[line[i],][3]
    }
    index <- which(Prob == max(Prob))
    actorOutput <- num_el[line[index[1]],][2]
    return(getName(name_id,actorOutput))
}
    
getParing("Watson, Emma (II)")
# Out:
# [1] Radcliffe, Daniel
# 113129 Levels: $hort, Too 2 Live Crew 50 Cent A., Randy A., Sergey ... Zyrianova, Maria

# %%
print(s)
# Out:
#  [1]       2     320  181766  252990  454474  912940  992668 1048576 1048894
# [10] 1230340 1301564 1503048 1961514 2041242
